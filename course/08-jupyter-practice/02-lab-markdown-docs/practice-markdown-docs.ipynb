# %% [markdown]
# # Практика: Markdown-документация в ноутбуке
#
# > **Модуль 8** — Оформление Jupyter-ноутбука с помощью Markdown.
#
# **Цель:** научиться документировать код, добавлять заголовки, списки и пояснения.

# %% [markdown]
# ## Контекст
#
# Ниже — код, который анализирует продажи за неделю. Сейчас он не документирован. Ваша задача — добавить Markdown-ячейки с описанием.

# %%
sales = [120, 95, 140, 88, 155, 200, 110]
days = ['Пн', 'Вт', 'Ср', 'Чт', 'Пт', 'Сб', 'Вс']
print(f"Сумма за неделю: {sum(sales)}")
print(f"Среднее: {sum(sales) / len(sales):.1f}")

# %% [markdown]
# ---
#
# ## Задание 1
#
# Добавьте **перед** этим кодом Markdown-ячейку с заголовком `### Исходные данные` и кратким описанием: что хранят переменные `sales` и `days`.

# %% [markdown]
# (Здесь должна быть ваша Markdown-ячейка перед кодом. Добавьте её вручную.)

# %% [markdown]
# ---
#
# ## Задание 2
#
# Добавьте **после** кода Markdown-ячейку с заголовком `### Результат` и маркированным списком: что выводит каждая строка `print`.

# %% [markdown]
# (Здесь ваша Markdown-ячейка с результатами.)

# %% [markdown]
# ---
#
# ## Задание 3
#
# Создайте Markdown-ячейку с заголовком `## Выводы` и кратким нумерованным списком (2–3 пункта) с выводами: например, в какой день продажи были максимальными, какой день — минимальным.

# %%
# Подсказка: max(sales), min(sales), days[sales.index(max(sales))]

# %% [markdown]
# (Добавьте Markdown-ячейку с выводами после выполнения кода выше.)
