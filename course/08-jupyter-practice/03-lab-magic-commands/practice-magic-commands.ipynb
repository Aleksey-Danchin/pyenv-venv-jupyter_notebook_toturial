# %% [markdown]
# # Практика: магические команды в Jupyter
#
# > **Модуль 8** — Использование магических команд в реальном сценарии.
#
# **Цель:** применить `%timeit`, `!pip`, `%env`, `%run` и др. в практической задаче.

# %% [markdown]
# ## Сценарий
#
# Вы проверяете окружение и производительность кода перед отчётом. Магические команды помогут сделать это прямо в ноутбуке.

# %%
# Этот код создаёт список из 100 000 элементов — мы будем замерять его время
def create_data(n=100000):
    return list(range(n))

# %% [markdown]
# ## Задание 1
#
# В **новой ячейке** используйте магическую команду `%timeit` с вызовом `create_data()` — замерьте, сколько времени занимает создание списка. Оставьте вывод в ячейке.

# %%
# Введите: %timeit create_data()

# %% [markdown]
# ## Задание 2
#
# В **новой ячейке** выполните команду `!pip list | head -5` — покажите первые 5 строк списка установленных пакетов. Или используйте `!pip show jupyter` чтобы увидеть метаданные Jupyter.

# %%
# Введите shell-команду с !

# %% [markdown]
# ## Задание 3
#
# Используйте магическую команду `%env` чтобы **вывести** текущие переменные окружения PATH и VIRTUAL_ENV (если venv активирован). В новой ячейке: `%env` — покажет все переменные.

# %%
# %env

# %% [markdown]
# ## Задание 4 (опционально)
#
# Создайте простой Python-скрипт `hello.py` в той же директории с содержимым `print('Hello from script!')`. В ячейке выполните `%run hello.py` — код скрипта выполнится в текущем ядре.

# %%
# %run hello.py
